# %% [markdown]
# # Inicio

# %%
# !pip install category_encoders
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import category_encoders as ce
from sklearn.linear_model import Perceptron
from sklearn.metrics import f1_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.utils import resample
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.10/dist-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Para test y train, creo dos features nuevas: el día de la semana y el rango de las horas.

# %%
columnas = ["attack_time", "watcher_country", "watcher_as_name", "attacker_country", "attacker_as_name", "attack_type", "watcher_uuid_enum", "attacker_ip_enum"]
X_test = pd.read_parquet("/content/drive/MyDrive/Colab Notebooks/test.parq", columns = columnas)
X_test = X_test.drop_duplicates(subset = ["attacker_ip_enum"])
X_test = X_test.sort_values(by = "attacker_ip_enum")
X_test
# Out:
#                        attack_time watcher_country  \
# 21502    2023-08-05 01:06:05+00:00              US
# 191      2023-07-30 07:48:36+00:00              LU
# 665517   2023-08-24 22:34:25+00:00              DE
# 72758    2023-07-31 15:06:25+00:00              US
# 37390    2023-07-31 12:51:27+00:00              GB
# ...                            ...             ...
# 17869691 2023-08-02 19:20:11+00:00              US
# 17977618 2023-08-29 01:54:37+00:00              DE
# 17862033 2023-08-02 01:09:27+00:00              US
# 17857346 2023-08-03 00:41:02+00:00              HK
# 18152743 2023-08-21 17:54:10+00:00              RU
#
#                              watcher_as_name attacker_country  \
# 21502                                 GOOGLE               KH
# 191                                  PONYNET               CA
# 665517                  ENTEGA Medianet GmbH               DE
# 72758                              A2HOSTING               IN
# 37390                       DIGITALOCEAN-ASN               CZ
# ...                                      ...              ...
# 17869691                             CONTABO               BR
# 17977618                 Hetzner Online GmbH               ZA
# 17862033               GOOGLE-CLOUD-PLATFORM               GB
# 17857346                           AMAZON-02               BH
# 18152743  Domain names registrar REG.RU, Ltd               RU
#
#                         attacker_as_name      attack_type  watcher_uuid_enum  \
# 21502          ANGKOR DATA COMMUNICATION  http:bruteforce              11357
# 191                              OVH SAS   ssh:bruteforce                259
# 665517                     Vodafone GmbH        http:scan              24879
# 72758           Threesa Infoway Pvt.Ltd.        http:spam               6292
# 37390                    Seznam.cz, a.s.        http:spam               6570
# ...                                  ...              ...                ...
# 17869691                          GOOGLE  unknown:unknown                332
# 17977618                        Afrihost   ssh:bruteforce              69717
# 17862033  Constantine Cybersecurity Ltd.        http:spam               6249
# 17857346   Kalaam Telecom Bahrain B.S.C.        http:spam              39538
# 18152743          JSC ER-Telecom Holding        http:spam              21480
#
#           attacker_ip_enum
# 21502                    5
# 191                      7
# 665517                  21
# 72758                   29
# 37390                   33
# ...                    ...
# 17869691            199947
# 17977618            199949
# 17862033            199962
# 17857346            199964
# 18152743            199966
#
# [49420 rows x 8 columns]

# %%
X_test_ip = X_test[["attacker_ip_enum"]]
X_test_ip
# Out:
#           attacker_ip_enum
# 21502                    5
# 191                      7
# 665517                  21
# 72758                   29
# 37390                   33
# ...                    ...
# 17869691            199947
# 17977618            199949
# 17862033            199962
# 17857346            199964
# 18152743            199966
#
# [49420 rows x 1 columns]

# %%
X_test["hour"] = X_test["attack_time"].dt.hour
X_test["hour_range"] = pd.cut(X_test["hour"], bins = [-1, 6, 12, 18, 23], labels = ["(0-6)","(6-12)", "(12-18)", "(18-0)"])
X_test["day"] = X_test["attack_time"].dt.day_name()
X_test = X_test.drop(["hour", "attack_time", "attacker_ip_enum"], axis = 1)
X_test
# Out:
#          watcher_country                     watcher_as_name attacker_country  \
# 21502                 US                              GOOGLE               KH
# 191                   LU                             PONYNET               CA
# 665517                DE                ENTEGA Medianet GmbH               DE
# 72758                 US                           A2HOSTING               IN
# 37390                 GB                    DIGITALOCEAN-ASN               CZ
# ...                  ...                                 ...              ...
# 17869691              US                             CONTABO               BR
# 17977618              DE                 Hetzner Online GmbH               ZA
# 17862033              US               GOOGLE-CLOUD-PLATFORM               GB
# 17857346              HK                           AMAZON-02               BH
# 18152743              RU  Domain names registrar REG.RU, Ltd               RU
#
#                         attacker_as_name      attack_type  watcher_uuid_enum  \
# 21502          ANGKOR DATA COMMUNICATION  http:bruteforce              11357
# 191                              OVH SAS   ssh:bruteforce                259
# 665517                     Vodafone GmbH        http:scan              24879
# 72758           Threesa Infoway Pvt.Ltd.        http:spam               6292
# 37390                    Seznam.cz, a.s.        http:spam               6570
# ...                                  ...              ...                ...
# 17869691                          GOOGLE  unknown:unknown                332
# 17977618                        Afrihost   ssh:bruteforce              69717
# 17862033  Constantine Cybersecurity Ltd.        http:spam               6249
# 17857346   Kalaam Telecom Bahrain B.S.C.        http:spam              39538
# 18152743          JSC ER-Telecom Holding        http:spam              21480
#
#          hour_range        day
# 21502         (0-6)   Saturday
# 191          (6-12)     Sunday
# 665517       (18-0)   Thursday
# 72758       (12-18)     Monday
# 37390        (6-12)     Monday
# ...             ...        ...
# 17869691     (18-0)  Wednesday
# 17977618      (0-6)    Tuesday
# 17862033      (0-6)  Wednesday
# 17857346      (0-6)   Thursday
# 18152743    (12-18)     Monday
#
# [49420 rows x 8 columns]

# %%
columnas = ["attack_time", "watcher_country", "watcher_as_name", "attacker_country", "attacker_as_name", "attack_type", "watcher_uuid_enum", "attacker_ip_enum", "label"]
train = pd.read_parquet("/content/drive/MyDrive/Colab Notebooks/train.parq", columns = columnas)
train
# Out:
#                        attack_time watcher_country  \
# 0        2023-07-31 07:17:51+00:00              DE
# 1        2023-07-31 07:17:51+00:00              DE
# 2        2023-07-31 07:17:49+00:00              DE
# 3        2023-07-31 07:17:49+00:00              DE
# 4        2023-07-31 07:17:49+00:00              DE
# ...                            ...             ...
# 61629680 2023-08-24 21:14:52+00:00              DE
# 61629681 2023-08-24 21:14:46+00:00              US
# 61629682 2023-08-24 21:14:46+00:00              US
# 61629683 2023-08-24 21:14:46+00:00              US
# 61629684 2023-08-24 21:14:46+00:00              US
#
#                                watcher_as_name attacker_country  \
# 0                             Host Europe GmbH               TR
# 1                             Host Europe GmbH               TR
# 2         bn:t Blatzheim Networks Telecom GmbH               DE
# 3         bn:t Blatzheim Networks Telecom GmbH               DE
# 4         bn:t Blatzheim Networks Telecom GmbH               DE
# ...                                        ...              ...
# 61629680                  ENTEGA Medianet GmbH               DE
# 61629681                         NAMECHEAP-NET               US
# 61629682                         NAMECHEAP-NET               US
# 61629683                         NAMECHEAP-NET               US
# 61629684                         NAMECHEAP-NET               US
#
#          attacker_as_name      attack_type  watcher_uuid_enum  \
# 0             Murat Aktas     http:exploit                  0
# 1             Murat Aktas        http:spam                  0
# 2            Contabo GmbH  http:bruteforce                  2
# 3            Contabo GmbH        http:spam                  2
# 4            Contabo GmbH     http:exploit                  2
# ...                   ...              ...                ...
# 61629680    Vodafone GmbH        http:scan              24879
# 61629681              WOW        http:scan              40383
# 61629682              WOW        http:spam              40383
# 61629683              WOW        http:spam              40383
# 61629684              WOW        http:scan              40383
#
#           attacker_ip_enum  label
# 0                     6466      0
# 1                     6466      0
# 2                     4637      0
# 3                     4637      0
# 4                     4637      0
# ...                    ...    ...
# 61629680            190784      0
# 61629681            193446      0
# 61629682            193446      0
# 61629683            193446      0
# 61629684            193446      0
#
# [61629685 rows x 9 columns]

# %% [markdown]
# Como voy a splitear el train para conseguir el set de validación, dropeo los duplicados para que no queden separados en diferentes sets y termine validando con la data aprendida en el entrenamiento.

# %%
train = train.drop_duplicates()
train = train.copy()
train
# Out:
#                        attack_time watcher_country  \
# 0        2023-07-31 07:17:51+00:00              DE
# 1        2023-07-31 07:17:51+00:00              DE
# 2        2023-07-31 07:17:49+00:00              DE
# 3        2023-07-31 07:17:49+00:00              DE
# 4        2023-07-31 07:17:49+00:00              DE
# ...                            ...             ...
# 61629671 2023-08-24 21:14:59+00:00              US
# 61629673 2023-08-24 21:14:59+00:00              US
# 61629674 2023-08-24 21:14:59+00:00              US
# 61629681 2023-08-24 21:14:46+00:00              US
# 61629682 2023-08-24 21:14:46+00:00              US
#
#                                watcher_as_name attacker_country  \
# 0                             Host Europe GmbH               TR
# 1                             Host Europe GmbH               TR
# 2         bn:t Blatzheim Networks Telecom GmbH               DE
# 3         bn:t Blatzheim Networks Telecom GmbH               DE
# 4         bn:t Blatzheim Networks Telecom GmbH               DE
# ...                                        ...              ...
# 61629671                              INMOTION               US
# 61629673                              INMOTION               US
# 61629674                              INMOTION               US
# 61629681                         NAMECHEAP-NET               US
# 61629682                         NAMECHEAP-NET               US
#
#          attacker_as_name      attack_type  watcher_uuid_enum  \
# 0             Murat Aktas     http:exploit                  0
# 1             Murat Aktas        http:spam                  0
# 2            Contabo GmbH  http:bruteforce                  2
# 3            Contabo GmbH        http:spam                  2
# 4            Contabo GmbH     http:exploit                  2
# ...                   ...              ...                ...
# 61629671    ATT-INTERNET4  http:bruteforce               9606
# 61629673    ATT-INTERNET4        http:scan               9606
# 61629674    ATT-INTERNET4     http:exploit               9606
# 61629681              WOW        http:scan              40383
# 61629682              WOW        http:spam              40383
#
#           attacker_ip_enum  label
# 0                     6466      0
# 1                     6466      0
# 2                     4637      0
# 3                     4637      0
# 4                     4637      0
# ...                    ...    ...
# 61629671            191439      0
# 61629673            191439      0
# 61629674            191439      0
# 61629681            193446      0
# 61629682            193446      0
#
# [40290308 rows x 9 columns]

# %%
train["hour"] = train["attack_time"].dt.hour
train["hour_range"] = pd.cut(train["hour"], bins = [-1, 6, 12, 18, 23], labels = ["(0-6)","(6-12)", "(12-18)", "(18-0)"])
train["day"] = train["attack_time"].dt.day_name()
train = train.drop(["hour", "attack_time"], axis = 1)
train
# Out:
#          watcher_country                       watcher_as_name  \
# 0                     DE                      Host Europe GmbH
# 1                     DE                      Host Europe GmbH
# 2                     DE  bn:t Blatzheim Networks Telecom GmbH
# 3                     DE  bn:t Blatzheim Networks Telecom GmbH
# 4                     DE  bn:t Blatzheim Networks Telecom GmbH
# ...                  ...                                   ...
# 61629671              US                              INMOTION
# 61629673              US                              INMOTION
# 61629674              US                              INMOTION
# 61629681              US                         NAMECHEAP-NET
# 61629682              US                         NAMECHEAP-NET
#
#          attacker_country attacker_as_name      attack_type  \
# 0                      TR      Murat Aktas     http:exploit
# 1                      TR      Murat Aktas        http:spam
# 2                      DE     Contabo GmbH  http:bruteforce
# 3                      DE     Contabo GmbH        http:spam
# 4                      DE     Contabo GmbH     http:exploit
# ...                   ...              ...              ...
# 61629671               US    ATT-INTERNET4  http:bruteforce
# 61629673               US    ATT-INTERNET4        http:scan
# 61629674               US    ATT-INTERNET4     http:exploit
# 61629681               US              WOW        http:scan
# 61629682               US              WOW        http:spam
#
#           watcher_uuid_enum  attacker_ip_enum  label hour_range       day
# 0                         0              6466      0     (6-12)    Monday
# 1                         0              6466      0     (6-12)    Monday
# 2                         2              4637      0     (6-12)    Monday
# 3                         2              4637      0     (6-12)    Monday
# 4                         2              4637      0     (6-12)    Monday
# ...                     ...               ...    ...        ...       ...
# 61629671               9606            191439      0     (18-0)  Thursday
# 61629673               9606            191439      0     (18-0)  Thursday
# 61629674               9606            191439      0     (18-0)  Thursday
# 61629681              40383            193446      0     (18-0)  Thursday
# 61629682              40383            193446      0     (18-0)  Thursday
#
# [40290308 rows x 10 columns]

# %% [markdown]
# # División de Train y Validation

# %% [markdown]
# ¿Cómo conviene obtener el dataset para validar? Conviene splitear los IPs únicos para que estén todos en el set de train o el de validación, y que no queden divididos en ambos.

# %%
train_set, validation_set = train_test_split(train["attacker_ip_enum"].unique(), test_size = 0.2, random_state = 18)

X_train = train[train["attacker_ip_enum"].isin(train_set)].drop("attacker_ip_enum", axis = 1)
X_validation = train[train["attacker_ip_enum"].isin(validation_set)].drop(["attacker_ip_enum", "label"], axis = 1)
y_validation = train[train["attacker_ip_enum"].isin(validation_set)]["label"]

# %%
label_zero = X_train.loc[X_train["label"] == 0]
label_one = X_train.loc[X_train["label"] == 1]

label_zero = resample(label_zero, replace = False, n_samples = len(label_one), random_state = 18)

X_train = pd.concat([label_zero, label_one])
y_train = X_train["label"]
X_train = X_train.drop("label", axis = 1)

# %%
X_train
# Out:
#          watcher_country     watcher_as_name attacker_country  \
# 49868872              FR    Host Europe GmbH               GB
# 12933149              DE          webgo GmbH               DE
# 55821067              FR             OVH SAS               ID
# 17126713              US            IONOS SE               US
# 50649241              US    DIGITALOCEAN-ASN               CN
# ...                  ...                 ...              ...
# 61629208              FR  Cyllene Lille Sasu               CA
# 61629247              DE           Strato AG               SG
# 61629250              DE           Strato AG               SG
# 61629389              DK         One.com A/S               SG
# 61629390              DK         One.com A/S               SG
#
#                      attacker_as_name      attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     http:exploit               3842
# 12933149          Hetzner Online GmbH        http:spam              11198
# 55821067  PT Telekomunikasi Indonesia     http:exploit              45864
# 17126713                 DREAMHOST-AS  http:bruteforce                 26
# 50649241                     Chinanet        http:spam               2119
# ...                               ...              ...                ...
# 61629208              AS-COLOCROSSING  unknown:unknown               1325
# 61629247             DIGITALOCEAN-ASN        http:spam              25180
# 61629250             DIGITALOCEAN-ASN        http:scan              25180
# 61629389             DIGITALOCEAN-ASN        http:scan              24258
# 61629390             DIGITALOCEAN-ASN        http:spam              24258
#
#          hour_range        day
# 49868872    (12-18)     Friday
# 12933149      (0-6)  Wednesday
# 55821067    (12-18)  Wednesday
# 17126713     (18-0)   Saturday
# 50649241    (12-18)     Monday
# ...             ...        ...
# 61629208     (6-12)  Wednesday
# 61629247     (18-0)   Thursday
# 61629250     (18-0)   Thursday
# 61629389     (18-0)   Thursday
# 61629390     (18-0)   Thursday
#
# [1078886 rows x 8 columns]

# %%
X_validation
# Out:
#          watcher_country            watcher_as_name attacker_country  \
# 57                    TR             Buuldy Bilisim               VN
# 66                    US  NETWORK-SOLUTIONS-HOSTING               MZ
# 67                    US  NETWORK-SOLUTIONS-HOSTING               MZ
# 68                    US  NETWORK-SOLUTIONS-HOSTING               MZ
# 82                    US  NETWORK-SOLUTIONS-HOSTING               MZ
# ...                  ...                        ...              ...
# 61629630              US           DIGITALOCEAN-ASN               TN
# 61629654              AL          One Albania Sh.a.               CH
# 61629657              FR                    OVH SAS               DE
# 61629658              FR                    OVH SAS               DE
# 61629668              US           DIGITALOCEAN-ASN               TN
#
#                                     attacker_as_name      attack_type  \
# 57        VIETNAM POSTS AND TELECOMMUNICATIONS GROUP         tcp:scan
# 66              Telecomunicacoes de Mocambique (TDM)        http:scan
# 67              Telecomunicacoes de Mocambique (TDM)        http:spam
# 68              Telecomunicacoes de Mocambique (TDM)  http:bruteforce
# 82              Telecomunicacoes de Mocambique (TDM)     http:exploit
# ...                                              ...              ...
# 61629630                             Tunisie-Telecom   ssh:bruteforce
# 61629654                             M247 Europe SRL         tcp:scan
# 61629657                            Host Europe GmbH        http:spam
# 61629658                            Host Europe GmbH     http:exploit
# 61629668                             Tunisie-Telecom   ssh:bruteforce
#
#           watcher_uuid_enum hour_range       day
# 57                       23     (6-12)    Monday
# 66                       27     (6-12)    Monday
# 67                       27     (6-12)    Monday
# 68                       27     (6-12)    Monday
# 82                       27     (6-12)    Monday
# ...                     ...        ...       ...
# 61629630              15752     (18-0)  Thursday
# 61629654              44853     (18-0)  Thursday
# 61629657               4290     (18-0)  Thursday
# 61629658               4290     (18-0)  Thursday
# 61629668              15752     (18-0)  Thursday
#
# [6871004 rows x 8 columns]

# %% [markdown]
# Encodeo todas las columnas con Mean Encoding porque era lo único que me funcionaba en el momento, pero sé que está mal y eso hace que me de un score bajo, ya que el perceptron es un modelo que hace promedios por sí mismo.

# %% [markdown]
# # Attacker Country

# %%
encoder = ce.TargetEncoder(cols = ["attacker_country"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#          watcher_country     watcher_as_name  attacker_country  \
# 49868872              FR    Host Europe GmbH          0.234559
# 12933149              DE          webgo GmbH          0.496955
# 55821067              FR             OVH SAS          0.087135
# 17126713              US            IONOS SE          0.519200
# 50649241              US    DIGITALOCEAN-ASN          0.283102
# ...                  ...                 ...               ...
# 61629208              FR  Cyllene Lille Sasu          0.739605
# 61629247              DE           Strato AG          0.627581
# 61629250              DE           Strato AG          0.627581
# 61629389              DK         One.com A/S          0.627581
# 61629390              DK         One.com A/S          0.627581
#
#                      attacker_as_name      attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     http:exploit               3842
# 12933149          Hetzner Online GmbH        http:spam              11198
# 55821067  PT Telekomunikasi Indonesia     http:exploit              45864
# 17126713                 DREAMHOST-AS  http:bruteforce                 26
# 50649241                     Chinanet        http:spam               2119
# ...                               ...              ...                ...
# 61629208              AS-COLOCROSSING  unknown:unknown               1325
# 61629247             DIGITALOCEAN-ASN        http:spam              25180
# 61629250             DIGITALOCEAN-ASN        http:scan              25180
# 61629389             DIGITALOCEAN-ASN        http:scan              24258
# 61629390             DIGITALOCEAN-ASN        http:spam              24258
#
#          hour_range        day
# 49868872    (12-18)     Friday
# 12933149      (0-6)  Wednesday
# 55821067    (12-18)  Wednesday
# 17126713     (18-0)   Saturday
# 50649241    (12-18)     Monday
# ...             ...        ...
# 61629208     (6-12)  Wednesday
# 61629247     (18-0)   Thursday
# 61629250     (18-0)   Thursday
# 61629389     (18-0)   Thursday
# 61629390     (18-0)   Thursday
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Day

# %%
encoder = ce.TargetEncoder(cols = ["day"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#          watcher_country     watcher_as_name  attacker_country  \
# 49868872              FR    Host Europe GmbH          0.234559
# 12933149              DE          webgo GmbH          0.496955
# 55821067              FR             OVH SAS          0.087135
# 17126713              US            IONOS SE          0.519200
# 50649241              US    DIGITALOCEAN-ASN          0.283102
# ...                  ...                 ...               ...
# 61629208              FR  Cyllene Lille Sasu          0.739605
# 61629247              DE           Strato AG          0.627581
# 61629250              DE           Strato AG          0.627581
# 61629389              DK         One.com A/S          0.627581
# 61629390              DK         One.com A/S          0.627581
#
#                      attacker_as_name      attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     http:exploit               3842
# 12933149          Hetzner Online GmbH        http:spam              11198
# 55821067  PT Telekomunikasi Indonesia     http:exploit              45864
# 17126713                 DREAMHOST-AS  http:bruteforce                 26
# 50649241                     Chinanet        http:spam               2119
# ...                               ...              ...                ...
# 61629208              AS-COLOCROSSING  unknown:unknown               1325
# 61629247             DIGITALOCEAN-ASN        http:spam              25180
# 61629250             DIGITALOCEAN-ASN        http:scan              25180
# 61629389             DIGITALOCEAN-ASN        http:scan              24258
# 61629390             DIGITALOCEAN-ASN        http:spam              24258
#
#          hour_range       day
# 49868872    (12-18)  0.487892
# 12933149      (0-6)  0.484710
# 55821067    (12-18)  0.484710
# 17126713     (18-0)  0.520245
# 50649241    (12-18)  0.503125
# ...             ...       ...
# 61629208     (6-12)  0.484710
# 61629247     (18-0)  0.471316
# 61629250     (18-0)  0.471316
# 61629389     (18-0)  0.471316
# 61629390     (18-0)  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Attack Type

# %%
encoder = ce.TargetEncoder(cols = ["attack_type"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#          watcher_country     watcher_as_name  attacker_country  \
# 49868872              FR    Host Europe GmbH          0.234559
# 12933149              DE          webgo GmbH          0.496955
# 55821067              FR             OVH SAS          0.087135
# 17126713              US            IONOS SE          0.519200
# 50649241              US    DIGITALOCEAN-ASN          0.283102
# ...                  ...                 ...               ...
# 61629208              FR  Cyllene Lille Sasu          0.739605
# 61629247              DE           Strato AG          0.627581
# 61629250              DE           Strato AG          0.627581
# 61629389              DK         One.com A/S          0.627581
# 61629390              DK         One.com A/S          0.627581
#
#                      attacker_as_name  attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     0.509254               3842
# 12933149          Hetzner Online GmbH     0.519763              11198
# 55821067  PT Telekomunikasi Indonesia     0.509254              45864
# 17126713                 DREAMHOST-AS     0.421215                 26
# 50649241                     Chinanet     0.519763               2119
# ...                               ...          ...                ...
# 61629208              AS-COLOCROSSING     0.312058               1325
# 61629247             DIGITALOCEAN-ASN     0.519763              25180
# 61629250             DIGITALOCEAN-ASN     0.508559              25180
# 61629389             DIGITALOCEAN-ASN     0.508559              24258
# 61629390             DIGITALOCEAN-ASN     0.519763              24258
#
#          hour_range       day
# 49868872    (12-18)  0.487892
# 12933149      (0-6)  0.484710
# 55821067    (12-18)  0.484710
# 17126713     (18-0)  0.520245
# 50649241    (12-18)  0.503125
# ...             ...       ...
# 61629208     (6-12)  0.484710
# 61629247     (18-0)  0.471316
# 61629250     (18-0)  0.471316
# 61629389     (18-0)  0.471316
# 61629390     (18-0)  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Hour Range

# %%
encoder = ce.TargetEncoder(cols = ["hour_range"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#          watcher_country     watcher_as_name  attacker_country  \
# 49868872              FR    Host Europe GmbH          0.234559
# 12933149              DE          webgo GmbH          0.496955
# 55821067              FR             OVH SAS          0.087135
# 17126713              US            IONOS SE          0.519200
# 50649241              US    DIGITALOCEAN-ASN          0.283102
# ...                  ...                 ...               ...
# 61629208              FR  Cyllene Lille Sasu          0.739605
# 61629247              DE           Strato AG          0.627581
# 61629250              DE           Strato AG          0.627581
# 61629389              DK         One.com A/S          0.627581
# 61629390              DK         One.com A/S          0.627581
#
#                      attacker_as_name  attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     0.509254               3842
# 12933149          Hetzner Online GmbH     0.519763              11198
# 55821067  PT Telekomunikasi Indonesia     0.509254              45864
# 17126713                 DREAMHOST-AS     0.421215                 26
# 50649241                     Chinanet     0.519763               2119
# ...                               ...          ...                ...
# 61629208              AS-COLOCROSSING     0.312058               1325
# 61629247             DIGITALOCEAN-ASN     0.519763              25180
# 61629250             DIGITALOCEAN-ASN     0.508559              25180
# 61629389             DIGITALOCEAN-ASN     0.508559              24258
# 61629390             DIGITALOCEAN-ASN     0.519763              24258
#
#           hour_range       day
# 49868872    0.492860  0.487892
# 12933149    0.502775  0.484710
# 55821067    0.492860  0.484710
# 17126713    0.492802  0.520245
# 50649241    0.492860  0.503125
# ...              ...       ...
# 61629208    0.507699  0.484710
# 61629247    0.492802  0.471316
# 61629250    0.492802  0.471316
# 61629389    0.492802  0.471316
# 61629390    0.492802  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Watcher Country

# %%
encoder = ce.TargetEncoder(cols = ["watcher_country"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#           watcher_country     watcher_as_name  attacker_country  \
# 49868872         0.484588    Host Europe GmbH          0.234559
# 12933149         0.471294          webgo GmbH          0.496955
# 55821067         0.484588             OVH SAS          0.087135
# 17126713         0.523600            IONOS SE          0.519200
# 50649241         0.523600    DIGITALOCEAN-ASN          0.283102
# ...                   ...                 ...               ...
# 61629208         0.484588  Cyllene Lille Sasu          0.739605
# 61629247         0.471294           Strato AG          0.627581
# 61629250         0.471294           Strato AG          0.627581
# 61629389         0.451857         One.com A/S          0.627581
# 61629390         0.451857         One.com A/S          0.627581
#
#                      attacker_as_name  attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     0.509254               3842
# 12933149          Hetzner Online GmbH     0.519763              11198
# 55821067  PT Telekomunikasi Indonesia     0.509254              45864
# 17126713                 DREAMHOST-AS     0.421215                 26
# 50649241                     Chinanet     0.519763               2119
# ...                               ...          ...                ...
# 61629208              AS-COLOCROSSING     0.312058               1325
# 61629247             DIGITALOCEAN-ASN     0.519763              25180
# 61629250             DIGITALOCEAN-ASN     0.508559              25180
# 61629389             DIGITALOCEAN-ASN     0.508559              24258
# 61629390             DIGITALOCEAN-ASN     0.519763              24258
#
#           hour_range       day
# 49868872    0.492860  0.487892
# 12933149    0.502775  0.484710
# 55821067    0.492860  0.484710
# 17126713    0.492802  0.520245
# 50649241    0.492860  0.503125
# ...              ...       ...
# 61629208    0.507699  0.484710
# 61629247    0.492802  0.471316
# 61629250    0.492802  0.471316
# 61629389    0.492802  0.471316
# 61629390    0.492802  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Watcher AS Name

# %%
encoder = ce.TargetEncoder(cols = ["watcher_as_name"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#           watcher_country  watcher_as_name  attacker_country  \
# 49868872         0.484588         0.561505          0.234559
# 12933149         0.471294         0.569955          0.496955
# 55821067         0.484588         0.470173          0.087135
# 17126713         0.523600         0.582416          0.519200
# 50649241         0.523600         0.469802          0.283102
# ...                   ...              ...               ...
# 61629208         0.484588         0.855536          0.739605
# 61629247         0.471294         0.585821          0.627581
# 61629250         0.471294         0.585821          0.627581
# 61629389         0.451857         0.479788          0.627581
# 61629390         0.451857         0.479788          0.627581
#
#                      attacker_as_name  attack_type  watcher_uuid_enum  \
# 49868872          Ans Academy Limited     0.509254               3842
# 12933149          Hetzner Online GmbH     0.519763              11198
# 55821067  PT Telekomunikasi Indonesia     0.509254              45864
# 17126713                 DREAMHOST-AS     0.421215                 26
# 50649241                     Chinanet     0.519763               2119
# ...                               ...          ...                ...
# 61629208              AS-COLOCROSSING     0.312058               1325
# 61629247             DIGITALOCEAN-ASN     0.519763              25180
# 61629250             DIGITALOCEAN-ASN     0.508559              25180
# 61629389             DIGITALOCEAN-ASN     0.508559              24258
# 61629390             DIGITALOCEAN-ASN     0.519763              24258
#
#           hour_range       day
# 49868872    0.492860  0.487892
# 12933149    0.502775  0.484710
# 55821067    0.492860  0.484710
# 17126713    0.492802  0.520245
# 50649241    0.492860  0.503125
# ...              ...       ...
# 61629208    0.507699  0.484710
# 61629247    0.492802  0.471316
# 61629250    0.492802  0.471316
# 61629389    0.492802  0.471316
# 61629390    0.492802  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Attacker AS Name

# %%
encoder = ce.TargetEncoder(cols = ["attacker_as_name"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#           watcher_country  watcher_as_name  attacker_country  \
# 49868872         0.484588         0.561505          0.234559
# 12933149         0.471294         0.569955          0.496955
# 55821067         0.484588         0.470173          0.087135
# 17126713         0.523600         0.582416          0.519200
# 50649241         0.523600         0.469802          0.283102
# ...                   ...              ...               ...
# 61629208         0.484588         0.855536          0.739605
# 61629247         0.471294         0.585821          0.627581
# 61629250         0.471294         0.585821          0.627581
# 61629389         0.451857         0.479788          0.627581
# 61629390         0.451857         0.479788          0.627581
#
#           attacker_as_name  attack_type  watcher_uuid_enum  hour_range  \
# 49868872          0.000000     0.509254               3842    0.492860
# 12933149          0.021568     0.519763              11198    0.502775
# 55821067          0.158694     0.509254              45864    0.492860
# 17126713          0.880239     0.421215                 26    0.492802
# 50649241          0.309295     0.519763               2119    0.492860
# ...                    ...          ...                ...         ...
# 61629208          0.907958     0.312058               1325    0.507699
# 61629247          0.710322     0.519763              25180    0.492802
# 61629250          0.710322     0.508559              25180    0.492802
# 61629389          0.710322     0.508559              24258    0.492802
# 61629390          0.710322     0.519763              24258    0.492802
#
#                day
# 49868872  0.487892
# 12933149  0.484710
# 55821067  0.484710
# 17126713  0.520245
# 50649241  0.503125
# ...            ...
# 61629208  0.484710
# 61629247  0.471316
# 61629250  0.471316
# 61629389  0.471316
# 61629390  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Watcher UUID Enum

# %%
encoder = ce.TargetEncoder(cols = ["watcher_uuid_enum"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)
X_train
# Out:
#           watcher_country  watcher_as_name  attacker_country  \
# 49868872         0.484588         0.561505          0.234559
# 12933149         0.471294         0.569955          0.496955
# 55821067         0.484588         0.470173          0.087135
# 17126713         0.523600         0.582416          0.519200
# 50649241         0.523600         0.469802          0.283102
# ...                   ...              ...               ...
# 61629208         0.484588         0.855536          0.739605
# 61629247         0.471294         0.585821          0.627581
# 61629250         0.471294         0.585821          0.627581
# 61629389         0.451857         0.479788          0.627581
# 61629390         0.451857         0.479788          0.627581
#
#           attacker_as_name  attack_type  watcher_uuid_enum  hour_range  \
# 49868872          0.000000     0.509254           0.214315    0.492860
# 12933149          0.021568     0.519763           0.381098    0.502775
# 55821067          0.158694     0.509254           0.408787    0.492860
# 17126713          0.880239     0.421215           0.439495    0.492802
# 50649241          0.309295     0.519763           0.562498    0.492860
# ...                    ...          ...                ...         ...
# 61629208          0.907958     0.312058           0.855536    0.507699
# 61629247          0.710322     0.519763           0.848755    0.492802
# 61629250          0.710322     0.508559           0.848755    0.492802
# 61629389          0.710322     0.508559           0.671476    0.492802
# 61629390          0.710322     0.519763           0.671476    0.492802
#
#                day
# 49868872  0.487892
# 12933149  0.484710
# 55821067  0.484710
# 17126713  0.520245
# 50649241  0.503125
# ...            ...
# 61629208  0.484710
# 61629247  0.471316
# 61629250  0.471316
# 61629389  0.471316
# 61629390  0.471316
#
# [1078886 rows x 8 columns]

# %% [markdown]
# # Perceptron

# %%
perceptron = Perceptron()

# %% [markdown]
# # Grid Search

# %%
# parametros = {
#     "penalty": ["l1", "l2", "elasticnet", None],
#     "max_iter": [100, 500, 1000, 2000],
#     "class_weight": [None, "balanced"]
# }

# grid_search = GridSearchCV(estimator = perceptron, param_grid = parametros, cv = 5, scoring = "f1", verbose = 2)
# grid_search.fit(X_train, y_train)

# hiperparametros = grid_search.best_params_

# perceptron_optimizado = Perceptron(
#     penalty = hiperparametros["penalty"],
#     max_iter = hiperparametros["max_iter"],
#     class_weight = hiperparametros["class_weight"]
# )

# perceptron_optimizado.fit(X_train, y_train)
# y_prediction = perceptron_optimizado.predict(X_validation)

# hiperparametros

# %%
# f1_score(y_validation, y_prediction)

# %% [markdown]
# # Random Search

# %% [markdown]
# Elijo estos hiperparámetros porque son los que consideré para obtener mejor score en el modelo.

# %%
parametros = {
    "penalty": ["l1", "l2", "elasticnet", None],
    "max_iter": randint(100, 2000),
    "class_weight": [None, "balanced"]
}

random_search = RandomizedSearchCV(estimator = perceptron, param_distributions = parametros, n_iter = 10, cv = 5, scoring = "f1", random_state = 18)
random_search.fit(X_train, y_train)

hiperparametros = random_search.best_params_

perceptron_optimizado = Perceptron(
    penalty = hiperparametros["penalty"],
    max_iter = hiperparametros["max_iter"],
    class_weight = hiperparametros["class_weight"]
)

perceptron_optimizado.fit(X_train, y_train)
y_prediction = perceptron_optimizado.predict(X_validation)

hiperparametros
# Out:
# {'class_weight': None, 'max_iter': 1487, 'penalty': 'l2'}

# %% [markdown]
# ¿Cuál es el mejor score de validación obtenido?

# %%
f1_score(y_validation, y_prediction)
# Out:
# 0.22182999898446232

# %%
accuracy_score(y_validation, y_prediction)
# Out:
# 0.8327178968313801

# %%
recall_score(y_validation, y_prediction)
# Out:
# 0.899663917231381

# %%
mean_absolute_error(y_validation, y_prediction)
# Out:
# 0.1672821031686199

# %%
mean_squared_error(y_validation, y_prediction)
# Out:
# 0.1672821031686199

# %% [markdown]
# Al predecir con este modelo para test, ¿Cúal es el score obtenido? (Guardar el csv con predicciones para entregarlo después)

# %%
y_prediction = perceptron_optimizado.predict(X_test)
y_prediction
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int8)

# %%
predictions = pd.DataFrame({"label": y_prediction}).reset_index(drop = True)
X_test_ip = X_test_ip.reset_index(drop = True)

predicciones = pd.concat([X_test_ip, predictions], axis = 1)
predicciones
# Out:
#        attacker_ip_enum  label
# 0                     5      0
# 1                     7      0
# 2                    21      0
# 3                    29      0
# 4                    33      0
# ...                 ...    ...
# 49415            199947      0
# 49416            199949      0
# 49417            199962      1
# 49418            199964      0
# 49419            199966      0
#
# [49420 rows x 2 columns]

# %% [markdown]
# El score obtenido es: 0.24467

# %%
predicciones.to_csv("/content/drive/MyDrive/Colab Notebooks/predicciones_perceptron_mean_encoding.csv", index = False)

# %% [markdown]
# https://drive.google.com/file/d/1Tq7MxPcPFj_gAQxgJLwm-6qB2diWpCgs/view?usp=drive_link

# %% [markdown]
# ¿Qué features son los más importantes para predecir con el mejor modelo? Graficar.

# %%
feature_importance = pd.DataFrame({"feature": X_train.columns, "coefficient": perceptron_optimizado.coef_.ravel()})
feature_importance["coefficient"] = feature_importance["coefficient"].abs()
feature_importance
# Out:
#              feature  coefficient
# 0    watcher_country     0.361151
# 1    watcher_as_name     0.719149
# 2   attacker_country     2.642195
# 3   attacker_as_name     6.690361
# 4        attack_type     3.048936
# 5  watcher_uuid_enum     7.426477
# 6         hour_range     0.030572
# 7                day     0.103217

# %%
feature_importance = feature_importance.reindex(feature_importance["coefficient"].sort_values(ascending = False).index)

plt.figure(figsize = (12, 8))
plt.barh(feature_importance["feature"], feature_importance["coefficient"], color = "#509FD4")
plt.title("Feature Importance")
plt.xlabel("Peso")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# Las features más importantes según este baseline son el tipo de ataque, el nombre del atacante y el número UUID del watcher.
