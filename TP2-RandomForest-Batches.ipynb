# %% [markdown]
# # Inicio

# %%
# !pip install category_encoders
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import category_encoders as ce
from sklearn.utils import resample
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.10/dist-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
columnas = ["attack_time", "watcher_country", "watcher_as_name", "attacker_country", "attacker_as_name", "attack_type", "attacker_ip_enum"]
X_test = pd.read_parquet("/content/drive/MyDrive/Colab Notebooks/test.parq", columns = columnas)
X_test = X_test.drop_duplicates(subset = ["attacker_ip_enum"])
X_test = X_test.sort_values(by = "attacker_ip_enum")
X_test
# Out:
#                        attack_time watcher_country  \
# 21502    2023-08-05 01:06:05+00:00              US
# 191      2023-07-30 07:48:36+00:00              LU
# 665517   2023-08-24 22:34:25+00:00              DE
# 72758    2023-07-31 15:06:25+00:00              US
# 37390    2023-07-31 12:51:27+00:00              GB
# ...                            ...             ...
# 17869691 2023-08-02 19:20:11+00:00              US
# 17977618 2023-08-29 01:54:37+00:00              DE
# 17862033 2023-08-02 01:09:27+00:00              US
# 17857346 2023-08-03 00:41:02+00:00              HK
# 18152743 2023-08-21 17:54:10+00:00              RU
#
#                              watcher_as_name attacker_country  \
# 21502                                 GOOGLE               KH
# 191                                  PONYNET               CA
# 665517                  ENTEGA Medianet GmbH               DE
# 72758                              A2HOSTING               IN
# 37390                       DIGITALOCEAN-ASN               CZ
# ...                                      ...              ...
# 17869691                             CONTABO               BR
# 17977618                 Hetzner Online GmbH               ZA
# 17862033               GOOGLE-CLOUD-PLATFORM               GB
# 17857346                           AMAZON-02               BH
# 18152743  Domain names registrar REG.RU, Ltd               RU
#
#                         attacker_as_name      attack_type  attacker_ip_enum
# 21502          ANGKOR DATA COMMUNICATION  http:bruteforce                 5
# 191                              OVH SAS   ssh:bruteforce                 7
# 665517                     Vodafone GmbH        http:scan                21
# 72758           Threesa Infoway Pvt.Ltd.        http:spam                29
# 37390                    Seznam.cz, a.s.        http:spam                33
# ...                                  ...              ...               ...
# 17869691                          GOOGLE  unknown:unknown            199947
# 17977618                        Afrihost   ssh:bruteforce            199949
# 17862033  Constantine Cybersecurity Ltd.        http:spam            199962
# 17857346   Kalaam Telecom Bahrain B.S.C.        http:spam            199964
# 18152743          JSC ER-Telecom Holding        http:spam            199966
#
# [49420 rows x 7 columns]

# %%
X_test_ip = X_test[["attacker_ip_enum"]]
X_test_ip
# Out:
#           attacker_ip_enum
# 21502                    5
# 191                      7
# 665517                  21
# 72758                   29
# 37390                   33
# ...                    ...
# 17869691            199947
# 17977618            199949
# 17862033            199962
# 17857346            199964
# 18152743            199966
#
# [49420 rows x 1 columns]

# %% [markdown]
# Para test y train, creo varias features: hora, rango de horas, día de la semana, divido tipo de ataque en protocolo y ataque, y país del atacante junto a la hora del ataque. Para las dos columnas de países, había diez que aparecían más veces, así que los que sobraban los agrupé en Otros países. Para la imputación de nulos de las dos columnas de nombres, tomé en cuenta al nombre que aparecía más veces en el país respectivo y le asigné ese. También cambié los tipos de todas las columnas para ahorrar memoria.

# %%
X_test["hour"] = X_test["attack_time"].dt.hour.astype("category")
X_test["hour_range"] = pd.cut(X_test["hour"], bins = [-1, 6, 12, 18, 23], labels = ["(0-6)","(6-12)", "(12-18)", "(18-0)"]).astype("category")
X_test["day"] = X_test["attack_time"].dt.day_name().astype("category")
X_test[["protocol", "attack"]] = X_test["attack_type"].str.split(":", expand = True).astype("category")

paises_attacker = ["US", "CA", "RU", "SG", "DE", "AU", "CN", "IN", "FR", "NL"]
paises_watcher = ["US", "DE", "FR", "GB", "NL", "PL", "CA", "SG", "RU", "BE"]
X_test["attacker_country"] = np.where(X_test["attacker_country"].isin(paises_attacker), X_test["attacker_country"], "Otros países")
X_test["attacker_country"] = X_test["attacker_country"].astype("category")
X_test["watcher_country"] = np.where(X_test["watcher_country"].isin(paises_watcher), X_test["watcher_country"], "Otros países")
X_test["watcher_country"] = X_test["watcher_country"].astype("category")

X_test["attacker_as_name"] = X_test.groupby("attacker_country")["attacker_as_name"].transform(lambda x: x.fillna(x.mode()[0]))
X_test["watcher_as_name"] = X_test.groupby("watcher_country")["watcher_as_name"].transform(lambda x: x.fillna(x.mode()[0]))

batches = np.array_split(X_test, 100)
batches_juntos = []
for batch in batches:
    batch["attacker_country_hour"] = batch["attacker_country"].astype(str) + "/" + batch["hour"].astype(str)
    batches_juntos.append(batch)
X_test = pd.concat(batches_juntos)
X_test["attacker_country_hour"] = X_test["attacker_country_hour"].astype("category")

X_test = X_test.drop(["attack_type", "attack_time", "attacker_ip_enum"], axis = 1)
X_test
# Out:
#          watcher_country                     watcher_as_name attacker_country  \
# 21502                 US                              GOOGLE     Otros países
# 191         Otros países                             PONYNET               CA
# 665517                DE                ENTEGA Medianet GmbH               DE
# 72758                 US                           A2HOSTING               IN
# 37390                 GB                    DIGITALOCEAN-ASN     Otros países
# ...                  ...                                 ...              ...
# 17869691              US                             CONTABO     Otros países
# 17977618              DE                 Hetzner Online GmbH     Otros países
# 17862033              US               GOOGLE-CLOUD-PLATFORM     Otros países
# 17857346    Otros países                           AMAZON-02     Otros países
# 18152743              RU  Domain names registrar REG.RU, Ltd               RU
#
#                         attacker_as_name hour hour_range        day protocol  \
# 21502          ANGKOR DATA COMMUNICATION    1      (0-6)   Saturday     http
# 191                              OVH SAS    7     (6-12)     Sunday      ssh
# 665517                     Vodafone GmbH   22     (18-0)   Thursday     http
# 72758           Threesa Infoway Pvt.Ltd.   15    (12-18)     Monday     http
# 37390                    Seznam.cz, a.s.   12     (6-12)     Monday     http
# ...                                  ...  ...        ...        ...      ...
# 17869691                          GOOGLE   19     (18-0)  Wednesday  unknown
# 17977618                        Afrihost    1      (0-6)    Tuesday      ssh
# 17862033  Constantine Cybersecurity Ltd.    1      (0-6)  Wednesday     http
# 17857346   Kalaam Telecom Bahrain B.S.C.    0      (0-6)   Thursday     http
# 18152743          JSC ER-Telecom Holding   17    (12-18)     Monday     http
#
#               attack attacker_country_hour
# 21502     bruteforce        Otros países/1
# 191       bruteforce                  CA/7
# 665517          scan                 DE/22
# 72758           spam                 IN/15
# 37390           spam       Otros países/12
# ...              ...                   ...
# 17869691     unknown       Otros países/19
# 17977618  bruteforce        Otros países/1
# 17862033        spam        Otros países/1
# 17857346        spam        Otros países/0
# 18152743        spam                 RU/17
#
# [49420 rows x 10 columns]

# %%
columnas = ["attack_time", "watcher_country", "watcher_as_name", "attacker_country", "attacker_as_name", "attack_type", "attacker_ip_enum", "label"]
train = pd.read_parquet("/content/drive/MyDrive/Colab Notebooks/train.parq", columns = columnas)
train
# Out:
#                        attack_time watcher_country  \
# 0        2023-07-31 07:17:51+00:00              DE
# 1        2023-07-31 07:17:51+00:00              DE
# 2        2023-07-31 07:17:49+00:00              DE
# 3        2023-07-31 07:17:49+00:00              DE
# 4        2023-07-31 07:17:49+00:00              DE
# ...                            ...             ...
# 61629680 2023-08-24 21:14:52+00:00              DE
# 61629681 2023-08-24 21:14:46+00:00              US
# 61629682 2023-08-24 21:14:46+00:00              US
# 61629683 2023-08-24 21:14:46+00:00              US
# 61629684 2023-08-24 21:14:46+00:00              US
#
#                                watcher_as_name attacker_country  \
# 0                             Host Europe GmbH               TR
# 1                             Host Europe GmbH               TR
# 2         bn:t Blatzheim Networks Telecom GmbH               DE
# 3         bn:t Blatzheim Networks Telecom GmbH               DE
# 4         bn:t Blatzheim Networks Telecom GmbH               DE
# ...                                        ...              ...
# 61629680                  ENTEGA Medianet GmbH               DE
# 61629681                         NAMECHEAP-NET               US
# 61629682                         NAMECHEAP-NET               US
# 61629683                         NAMECHEAP-NET               US
# 61629684                         NAMECHEAP-NET               US
#
#          attacker_as_name      attack_type  attacker_ip_enum  label
# 0             Murat Aktas     http:exploit              6466      0
# 1             Murat Aktas        http:spam              6466      0
# 2            Contabo GmbH  http:bruteforce              4637      0
# 3            Contabo GmbH        http:spam              4637      0
# 4            Contabo GmbH     http:exploit              4637      0
# ...                   ...              ...               ...    ...
# 61629680    Vodafone GmbH        http:scan            190784      0
# 61629681              WOW        http:scan            193446      0
# 61629682              WOW        http:spam            193446      0
# 61629683              WOW        http:spam            193446      0
# 61629684              WOW        http:scan            193446      0
#
# [61629685 rows x 8 columns]

# %% [markdown]
# Como voy a splitear el train para conseguir el set de validación, dropeo los duplicados para que no queden separados en diferentes sets y termine validando con la data aprendida en el entrenamiento.

# %%
train = train.drop_duplicates()
train = train.copy()
train
# Out:
#                        attack_time watcher_country  \
# 0        2023-07-31 07:17:51+00:00              DE
# 1        2023-07-31 07:17:51+00:00              DE
# 2        2023-07-31 07:17:49+00:00              DE
# 3        2023-07-31 07:17:49+00:00              DE
# 4        2023-07-31 07:17:49+00:00              DE
# ...                            ...             ...
# 61629671 2023-08-24 21:14:59+00:00              US
# 61629673 2023-08-24 21:14:59+00:00              US
# 61629674 2023-08-24 21:14:59+00:00              US
# 61629681 2023-08-24 21:14:46+00:00              US
# 61629682 2023-08-24 21:14:46+00:00              US
#
#                                watcher_as_name attacker_country  \
# 0                             Host Europe GmbH               TR
# 1                             Host Europe GmbH               TR
# 2         bn:t Blatzheim Networks Telecom GmbH               DE
# 3         bn:t Blatzheim Networks Telecom GmbH               DE
# 4         bn:t Blatzheim Networks Telecom GmbH               DE
# ...                                        ...              ...
# 61629671                              INMOTION               US
# 61629673                              INMOTION               US
# 61629674                              INMOTION               US
# 61629681                         NAMECHEAP-NET               US
# 61629682                         NAMECHEAP-NET               US
#
#          attacker_as_name      attack_type  attacker_ip_enum  label
# 0             Murat Aktas     http:exploit              6466      0
# 1             Murat Aktas        http:spam              6466      0
# 2            Contabo GmbH  http:bruteforce              4637      0
# 3            Contabo GmbH        http:spam              4637      0
# 4            Contabo GmbH     http:exploit              4637      0
# ...                   ...              ...               ...    ...
# 61629671    ATT-INTERNET4  http:bruteforce            191439      0
# 61629673    ATT-INTERNET4        http:scan            191439      0
# 61629674    ATT-INTERNET4     http:exploit            191439      0
# 61629681              WOW        http:scan            193446      0
# 61629682              WOW        http:spam            193446      0
#
# [40238870 rows x 8 columns]

# %%
train["hour"] = train["attack_time"].dt.hour.astype("category")
train["hour_range"] = pd.cut(train["hour"], bins = [-1, 6, 12, 18, 23], labels = ["(0-6)","(6-12)", "(12-18)", "(18-0)"]).astype("category")
train["day"] = train["attack_time"].dt.day_name().astype("category")
train[["protocol", "attack"]] = train["attack_type"].str.split(":", expand = True).astype("category")

train["attacker_country"] = np.where(train["attacker_country"].isin(paises_attacker), train["attacker_country"], "Otros países")
train["attacker_country"] = train["attacker_country"].astype("category")
train["watcher_country"] = np.where(train["watcher_country"].isin(paises_watcher), train["watcher_country"], "Otros países")
train["watcher_country"] = train["watcher_country"].astype("category")

train["attacker_as_name"] = train.groupby("attacker_country")["attacker_as_name"].transform(lambda x: x.fillna(x.mode()[0]))
train["watcher_as_name"] = train.groupby("watcher_country")["watcher_as_name"].transform(lambda x: x.fillna(x.mode()[0]))

batches = np.array_split(train, 100)
batches_juntos = []
for batch in batches:
    batch["attacker_country_hour"] = batch["attacker_country"].astype(str) + "/" + batch["hour"].astype(str)
    batches_juntos.append(batch)
train = pd.concat(batches_juntos)
train["attacker_country_hour"] = train["attacker_country_hour"].astype("category")

train = train.drop(["attack_type", "attack_time"], axis = 1)
train
# Out:
#          watcher_country                       watcher_as_name  \
# 0                     DE                      Host Europe GmbH
# 1                     DE                      Host Europe GmbH
# 2                     DE  bn:t Blatzheim Networks Telecom GmbH
# 3                     DE  bn:t Blatzheim Networks Telecom GmbH
# 4                     DE  bn:t Blatzheim Networks Telecom GmbH
# ...                  ...                                   ...
# 61629671              US                              INMOTION
# 61629673              US                              INMOTION
# 61629674              US                              INMOTION
# 61629681              US                         NAMECHEAP-NET
# 61629682              US                         NAMECHEAP-NET
#
#          attacker_country attacker_as_name  attacker_ip_enum  label hour  \
# 0            Otros países      Murat Aktas              6466      0    7
# 1            Otros países      Murat Aktas              6466      0    7
# 2                      DE     Contabo GmbH              4637      0    7
# 3                      DE     Contabo GmbH              4637      0    7
# 4                      DE     Contabo GmbH              4637      0    7
# ...                   ...              ...               ...    ...  ...
# 61629671               US    ATT-INTERNET4            191439      0   21
# 61629673               US    ATT-INTERNET4            191439      0   21
# 61629674               US    ATT-INTERNET4            191439      0   21
# 61629681               US              WOW            193446      0   21
# 61629682               US              WOW            193446      0   21
#
#          hour_range       day protocol      attack attacker_country_hour
# 0            (6-12)    Monday     http     exploit        Otros países/7
# 1            (6-12)    Monday     http        spam        Otros países/7
# 2            (6-12)    Monday     http  bruteforce                  DE/7
# 3            (6-12)    Monday     http        spam                  DE/7
# 4            (6-12)    Monday     http     exploit                  DE/7
# ...             ...       ...      ...         ...                   ...
# 61629671     (18-0)  Thursday     http  bruteforce                 US/21
# 61629673     (18-0)  Thursday     http        scan                 US/21
# 61629674     (18-0)  Thursday     http     exploit                 US/21
# 61629681     (18-0)  Thursday     http        scan                 US/21
# 61629682     (18-0)  Thursday     http        spam                 US/21
#
# [40238870 rows x 12 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40238870 entries, 0 to 61629682
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   watcher_country        category
#  1   watcher_as_name        category
#  2   attacker_country       category
#  3   attacker_as_name       category
#  4   attacker_ip_enum       int32
#  5   label                  int8
#  6   hour                   category
#  7   hour_range             category
#  8   day                    category
#  9   protocol               category
#  10  attack                 category
#  11  attacker_country_hour  category
# dtypes: category(10), int32(1), int8(1)
# memory usage: 998.2 MB

# %% [markdown]
# # División de Train y Validation

# %% [markdown]
# ¿Cómo conviene elegir los datos de validación respecto de los de train? Conviene que los IPs que estén en train, no estén en el de validación, porque si no solo estaría memorizando lo aprendido.

# %%
train_set, validation_set = train_test_split(train["attacker_ip_enum"].unique(), test_size = 0.2, random_state = 18)

X_train = train[train["attacker_ip_enum"].isin(train_set)].drop("attacker_ip_enum", axis = 1)
X_validation = train[train["attacker_ip_enum"].isin(validation_set)].drop(["attacker_ip_enum", "label"], axis = 1)
y_validation = train[train["attacker_ip_enum"].isin(validation_set)]["label"]

label_zero = X_train.loc[X_train["label"] == 0]
label_one = X_train.loc[X_train["label"] == 1]

label_zero = resample(label_zero, replace = False, n_samples = len(label_one) + 10000000, random_state = 18)

X_train = pd.concat([label_zero, label_one])
y_train = X_train["label"]
X_train = X_train.drop("label", axis = 1)

# %%
del train
del batch
del batches
del batches_juntos

# %%
X_train
# Out:
#          watcher_country        watcher_as_name attacker_country  \
# 46466580              US                 HVC-AS               CN
# 35466168              DE   ENTEGA Medianet GmbH               DE
# 32971698    Otros países       Datacamp Limited               CN
# 14102806              US  GOOGLE-CLOUD-PLATFORM     Otros países
# 38449210              DE   ENTEGA Medianet GmbH               DE
# ...                  ...                    ...              ...
# 61629208              FR     Cyllene Lille Sasu               CA
# 61629247              DE              Strato AG               SG
# 61629250              DE              Strato AG               SG
# 61629389    Otros países            One.com A/S               SG
# 61629390    Otros países            One.com A/S               SG
#
#                        attacker_as_name hour hour_range        day protocol  \
# 46466580                CT-HangZhou-IDC   12     (6-12)     Monday     http
# 35466168  1&1 Versatel Deutschland GmbH    4      (0-6)   Saturday     http
# 32971698                       Chinanet   12     (6-12)     Monday      ssh
# 14102806            StarNet Solutii SRL   14    (12-18)     Friday     http
# 38449210            Deutsche Telekom AG   11     (6-12)     Friday     http
# ...                                 ...  ...        ...        ...      ...
# 61629208                AS-COLOCROSSING    9     (6-12)  Wednesday  unknown
# 61629247               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629250               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629389               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629390               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 10 columns]

# %%
X_validation
# Out:
#          watcher_country            watcher_as_name attacker_country  \
# 57          Otros países             Buuldy Bilisim     Otros países
# 66                    US  NETWORK-SOLUTIONS-HOSTING     Otros países
# 67                    US  NETWORK-SOLUTIONS-HOSTING     Otros países
# 68                    US  NETWORK-SOLUTIONS-HOSTING     Otros países
# 82                    US  NETWORK-SOLUTIONS-HOSTING     Otros países
# ...                  ...                        ...              ...
# 61629630              US           DIGITALOCEAN-ASN     Otros países
# 61629654    Otros países          One Albania Sh.a.     Otros países
# 61629657              FR                    OVH SAS               DE
# 61629658              FR                    OVH SAS               DE
# 61629668              US           DIGITALOCEAN-ASN     Otros países
#
#                                     attacker_as_name hour hour_range  \
# 57        VIETNAM POSTS AND TELECOMMUNICATIONS GROUP    7     (6-12)
# 66              Telecomunicacoes de Mocambique (TDM)    7     (6-12)
# 67              Telecomunicacoes de Mocambique (TDM)    7     (6-12)
# 68              Telecomunicacoes de Mocambique (TDM)    7     (6-12)
# 82              Telecomunicacoes de Mocambique (TDM)    7     (6-12)
# ...                                              ...  ...        ...
# 61629630                             Tunisie-Telecom   21     (18-0)
# 61629654                             M247 Europe SRL   21     (18-0)
# 61629657                            Host Europe GmbH   21     (18-0)
# 61629658                            Host Europe GmbH   21     (18-0)
# 61629668                             Tunisie-Telecom   21     (18-0)
#
#                day protocol      attack attacker_country_hour
# 57          Monday      tcp        scan        Otros países/7
# 66          Monday     http        scan        Otros países/7
# 67          Monday     http        spam        Otros países/7
# 68          Monday     http  bruteforce        Otros países/7
# 82          Monday     http     exploit        Otros países/7
# ...            ...      ...         ...                   ...
# 61629630  Thursday      ssh  bruteforce       Otros países/21
# 61629654  Thursday      tcp        scan       Otros países/21
# 61629657  Thursday     http        spam                 DE/21
# 61629658  Thursday     http     exploit                 DE/21
# 61629668  Thursday      ssh  bruteforce       Otros países/21
#
# [6860979 rows x 10 columns]

# %% [markdown]
# Para todos los encodings decidí cambiarle el tipo a cada columna para ahorrar memoria, ya que algunas quedaban con int64 o float64, dependiendo la bibliotea.

# %% [markdown]
# # Watcher Country

# %% [markdown]
# Uso Binary Encoding para watcher_country y attacker_country porque no son pocos países para usar One Hot Encoding, pero tampoco muchos para Mean Encoding.

# %%
encoder = ce.BinaryEncoder(cols = ["watcher_country"])
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["watcher_country_0", "watcher_country_1", "watcher_country_2", "watcher_country_3"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3        watcher_as_name attacker_country  \
# 46466580                  1                 HVC-AS               CN
# 35466168                  0   ENTEGA Medianet GmbH               DE
# 32971698                  1       Datacamp Limited               CN
# 14102806                  1  GOOGLE-CLOUD-PLATFORM     Otros países
# 38449210                  0   ENTEGA Medianet GmbH               DE
# ...                     ...                    ...              ...
# 61629208                  0     Cyllene Lille Sasu               CA
# 61629247                  0              Strato AG               SG
# 61629250                  0              Strato AG               SG
# 61629389                  1            One.com A/S               SG
# 61629390                  1            One.com A/S               SG
#
#                        attacker_as_name hour hour_range        day protocol  \
# 46466580                CT-HangZhou-IDC   12     (6-12)     Monday     http
# 35466168  1&1 Versatel Deutschland GmbH    4      (0-6)   Saturday     http
# 32971698                       Chinanet   12     (6-12)     Monday      ssh
# 14102806            StarNet Solutii SRL   14    (12-18)     Friday     http
# 38449210            Deutsche Telekom AG   11     (6-12)     Friday     http
# ...                                 ...  ...        ...        ...      ...
# 61629208                AS-COLOCROSSING    9     (6-12)  Wednesday  unknown
# 61629247               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629250               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629389               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629390               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 13 columns]

# %% [markdown]
# # Watcher AS Name

# %% [markdown]
# Uso Mean Encoding para watcher_as_name y attacker_as_name porque hay muchos nombres diferentes en cada columna.

# %%
encoder = ce.TargetEncoder(cols = ["watcher_as_name"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

X_train["watcher_as_name"] = X_train["watcher_as_name"].astype("float32")
X_validation["watcher_as_name"] = X_validation["watcher_as_name"].astype("float32")
X_test["watcher_as_name"] = X_test["watcher_as_name"].astype("float32")
X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name attacker_country  \
# 46466580                  1         0.053534               CN
# 35466168                  0         0.009843               DE
# 32971698                  1         0.050879               CN
# 14102806                  1         0.065808     Otros países
# 38449210                  0         0.009843               DE
# ...                     ...              ...              ...
# 61629208                  0         0.207164               CA
# 61629247                  0         0.071613               SG
# 61629250                  0         0.071613               SG
# 61629389                  1         0.045860               SG
# 61629390                  1         0.045860               SG
#
#                        attacker_as_name hour hour_range        day protocol  \
# 46466580                CT-HangZhou-IDC   12     (6-12)     Monday     http
# 35466168  1&1 Versatel Deutschland GmbH    4      (0-6)   Saturday     http
# 32971698                       Chinanet   12     (6-12)     Monday      ssh
# 14102806            StarNet Solutii SRL   14    (12-18)     Friday     http
# 38449210            Deutsche Telekom AG   11     (6-12)     Friday     http
# ...                                 ...  ...        ...        ...      ...
# 61629208                AS-COLOCROSSING    9     (6-12)  Wednesday  unknown
# 61629247               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629250               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629389               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629390               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 13 columns]

# %% [markdown]
# # Attacker Country

# %%
encoder = ce.BinaryEncoder(cols = ["attacker_country"])
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["attacker_country_0", "attacker_country_1", "attacker_country_2", "attacker_country_3"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#                        attacker_as_name hour hour_range        day protocol  \
# 46466580                CT-HangZhou-IDC   12     (6-12)     Monday     http
# 35466168  1&1 Versatel Deutschland GmbH    4      (0-6)   Saturday     http
# 32971698                       Chinanet   12     (6-12)     Monday      ssh
# 14102806            StarNet Solutii SRL   14    (12-18)     Friday     http
# 38449210            Deutsche Telekom AG   11     (6-12)     Friday     http
# ...                                 ...  ...        ...        ...      ...
# 61629208                AS-COLOCROSSING    9     (6-12)  Wednesday  unknown
# 61629247               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629250               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629389               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
# 61629390               DIGITALOCEAN-ASN   21     (18-0)   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 16 columns]

# %% [markdown]
# # Attacker AS Name

# %%
encoder = ce.TargetEncoder(cols = ["attacker_as_name"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

X_train["attacker_as_name"] = X_train["attacker_as_name"].astype("float32")
X_validation["attacker_as_name"] = X_validation["attacker_as_name"].astype("float32")
X_test["attacker_as_name"] = X_test["attacker_as_name"].astype("float32")
X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name hour hour_range        day protocol      attack  \
# 46466580          0.000000   12     (6-12)     Monday     http        scan
# 35466168          0.000000    4      (0-6)   Saturday     http        scan
# 32971698          0.022648   12     (6-12)     Monday      ssh  bruteforce
# 14102806          0.000000   14    (12-18)     Friday     http     exploit
# 38449210          0.000000   11     (6-12)     Friday     http        scan
# ...                    ...  ...        ...        ...      ...         ...
# 61629208          0.334415    9     (6-12)  Wednesday  unknown     unknown
# 61629247          0.111315   21     (18-0)   Thursday     http        spam
# 61629250          0.111315   21     (18-0)   Thursday     http        scan
# 61629389          0.111315   21     (18-0)   Thursday     http        scan
# 61629390          0.111315   21     (18-0)   Thursday     http        spam
#
#          attacker_country_hour
# 46466580                 CN/12
# 35466168                  DE/4
# 32971698                 CN/12
# 14102806       Otros países/14
# 38449210                 DE/11
# ...                        ...
# 61629208                  CA/9
# 61629247                 SG/21
# 61629250                 SG/21
# 61629389                 SG/21
# 61629390                 SG/21
#
# [11077372 rows x 16 columns]

# %% [markdown]
# # Hour Range

# %% [markdown]
# Uso One Hot Encoding para hour_range, ya que solo hay cuatro valores en la columna.

# %%
encoder = ce.OneHotEncoder(cols = ["hour_range"], use_cat_names = True)
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["hour_range_(0-6)", "hour_range_(6-12)", "hour_range_(12-18)", "hour_range_(18-0)"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name hour  hour_range_(0-6)  hour_range_(6-12)  \
# 46466580          0.000000   12                 0                  1
# 35466168          0.000000    4                 1                  0
# 32971698          0.022648   12                 0                  1
# 14102806          0.000000   14                 0                  0
# 38449210          0.000000   11                 0                  1
# ...                    ...  ...               ...                ...
# 61629208          0.334415    9                 0                  1
# 61629247          0.111315   21                 0                  0
# 61629250          0.111315   21                 0                  0
# 61629389          0.111315   21                 0                  0
# 61629390          0.111315   21                 0                  0
#
#           hour_range_(12-18)  hour_range_(18-0)        day protocol  \
# 46466580                   0                  0     Monday     http
# 35466168                   0                  0   Saturday     http
# 32971698                   0                  0     Monday      ssh
# 14102806                   1                  0     Friday     http
# 38449210                   0                  0     Friday     http
# ...                      ...                ...        ...      ...
# 61629208                   0                  0  Wednesday  unknown
# 61629247                   0                  1   Thursday     http
# 61629250                   0                  1   Thursday     http
# 61629389                   0                  1   Thursday     http
# 61629390                   0                  1   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 19 columns]

# %% [markdown]
# # Hour

# %% [markdown]
# Para la columna hour decidí normalizar la columna entre 0 y 1 porque hay 24 valores númericos diferentes con mucha varianza entre sí.

# %%
scaler = MinMaxScaler()

X_train["hour"] = scaler.fit_transform(X_train["hour"].values.reshape(-1, 1))
X_validation["hour"] = scaler.transform(X_validation["hour"].values.reshape(-1, 1))
X_test["hour"] = scaler.transform(X_test["hour"].values.reshape(-1, 1))

X_train["hour"] = X_train["hour"].astype("float32")
X_validation["hour"] = X_validation["hour"].astype("float32")
X_test["hour"] = X_test["hour"].astype("float32")
X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name      hour  hour_range_(0-6)  hour_range_(6-12)  \
# 46466580          0.000000  0.521739                 0                  1
# 35466168          0.000000  0.173913                 1                  0
# 32971698          0.022648  0.521739                 0                  1
# 14102806          0.000000  0.608696                 0                  0
# 38449210          0.000000  0.478261                 0                  1
# ...                    ...       ...               ...                ...
# 61629208          0.334415  0.391304                 0                  1
# 61629247          0.111315  0.913043                 0                  0
# 61629250          0.111315  0.913043                 0                  0
# 61629389          0.111315  0.913043                 0                  0
# 61629390          0.111315  0.913043                 0                  0
#
#           hour_range_(12-18)  hour_range_(18-0)        day protocol  \
# 46466580                   0                  0     Monday     http
# 35466168                   0                  0   Saturday     http
# 32971698                   0                  0     Monday      ssh
# 14102806                   1                  0     Friday     http
# 38449210                   0                  0     Friday     http
# ...                      ...                ...        ...      ...
# 61629208                   0                  0  Wednesday  unknown
# 61629247                   0                  1   Thursday     http
# 61629250                   0                  1   Thursday     http
# 61629389                   0                  1   Thursday     http
# 61629390                   0                  1   Thursday     http
#
#               attack attacker_country_hour
# 46466580        scan                 CN/12
# 35466168        scan                  DE/4
# 32971698  bruteforce                 CN/12
# 14102806     exploit       Otros países/14
# 38449210        scan                 DE/11
# ...              ...                   ...
# 61629208     unknown                  CA/9
# 61629247        spam                 SG/21
# 61629250        scan                 SG/21
# 61629389        scan                 SG/21
# 61629390        spam                 SG/21
#
# [11077372 rows x 19 columns]

# %% [markdown]
# # Day

# %% [markdown]
# Uso Binary Encoder para la columna day porque son los siete días de la semana.

# %%
encoder = ce.BinaryEncoder(cols = ["day"])
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["day_0", "day_1", "day_2"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name  ...  hour_range_(0-6)  hour_range_(6-12)  \
# 46466580          0.000000  ...                 0                  1
# 35466168          0.000000  ...                 1                  0
# 32971698          0.022648  ...                 0                  1
# 14102806          0.000000  ...                 0                  0
# 38449210          0.000000  ...                 0                  1
# ...                    ...  ...               ...                ...
# 61629208          0.334415  ...                 0                  1
# 61629247          0.111315  ...                 0                  0
# 61629250          0.111315  ...                 0                  0
# 61629389          0.111315  ...                 0                  0
# 61629390          0.111315  ...                 0                  0
#
#           hour_range_(12-18)  hour_range_(18-0)  day_0  day_1  day_2  \
# 46466580                   0                  0      0      0      1
# 35466168                   0                  0      0      1      0
# 32971698                   0                  0      0      0      1
# 14102806                   1                  0      0      1      1
# 38449210                   0                  0      0      1      1
# ...                      ...                ...    ...    ...    ...
# 61629208                   0                  0      1      0      0
# 61629247                   0                  1      1      0      1
# 61629250                   0                  1      1      0      1
# 61629389                   0                  1      1      0      1
# 61629390                   0                  1      1      0      1
#
#           protocol      attack attacker_country_hour
# 46466580      http        scan                 CN/12
# 35466168      http        scan                  DE/4
# 32971698       ssh  bruteforce                 CN/12
# 14102806      http     exploit       Otros países/14
# 38449210      http        scan                 DE/11
# ...            ...         ...                   ...
# 61629208   unknown     unknown                  CA/9
# 61629247      http        spam                 SG/21
# 61629250      http        scan                 SG/21
# 61629389      http        scan                 SG/21
# 61629390      http        spam                 SG/21
#
# [11077372 rows x 21 columns]

# %% [markdown]
# # Protocol

# %% [markdown]
# En protocol y attack uso Binary Encoding porque hay muchos datos en ambas columnas.

# %%
encoder = ce.BinaryEncoder(cols = ["protocol"])
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["protocol_0", "protocol_1", "protocol_2", "protocol_3"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name  ...  hour_range_(18-0)  day_0  day_1  day_2  \
# 46466580          0.000000  ...                  0      0      0      1
# 35466168          0.000000  ...                  0      0      1      0
# 32971698          0.022648  ...                  0      0      0      1
# 14102806          0.000000  ...                  0      0      1      1
# 38449210          0.000000  ...                  0      0      1      1
# ...                    ...  ...                ...    ...    ...    ...
# 61629208          0.334415  ...                  0      1      0      0
# 61629247          0.111315  ...                  1      1      0      1
# 61629250          0.111315  ...                  1      1      0      1
# 61629389          0.111315  ...                  1      1      0      1
# 61629390          0.111315  ...                  1      1      0      1
#
#           protocol_0  protocol_1  protocol_2  protocol_3      attack  \
# 46466580           0           0           0           1        scan
# 35466168           0           0           0           1        scan
# 32971698           0           0           1           0  bruteforce
# 14102806           0           0           0           1     exploit
# 38449210           0           0           0           1        scan
# ...              ...         ...         ...         ...         ...
# 61629208           0           0           1           1     unknown
# 61629247           0           0           0           1        spam
# 61629250           0           0           0           1        scan
# 61629389           0           0           0           1        scan
# 61629390           0           0           0           1        spam
#
#           attacker_country_hour
# 46466580                  CN/12
# 35466168                   DE/4
# 32971698                  CN/12
# 14102806        Otros países/14
# 38449210                  DE/11
# ...                         ...
# 61629208                   CA/9
# 61629247                  SG/21
# 61629250                  SG/21
# 61629389                  SG/21
# 61629390                  SG/21
#
# [11077372 rows x 24 columns]

# %% [markdown]
# # Attack

# %%
encoder = ce.BinaryEncoder(cols = ["attack"])
X_train = encoder.fit_transform(X_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

columnas = ["attack_0", "attack_1", "attack_2"]
X_train[columnas] = X_train[columnas].astype("int8")
X_validation[columnas] = X_validation[columnas].astype("int8")
X_test[columnas] = X_test[columnas].astype("int8")

X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name  ...  day_1  day_2  protocol_0  protocol_1  \
# 46466580          0.000000  ...      0      1           0           0
# 35466168          0.000000  ...      1      0           0           0
# 32971698          0.022648  ...      0      1           0           0
# 14102806          0.000000  ...      1      1           0           0
# 38449210          0.000000  ...      1      1           0           0
# ...                    ...  ...    ...    ...         ...         ...
# 61629208          0.334415  ...      0      0           0           0
# 61629247          0.111315  ...      0      1           0           0
# 61629250          0.111315  ...      0      1           0           0
# 61629389          0.111315  ...      0      1           0           0
# 61629390          0.111315  ...      0      1           0           0
#
#           protocol_2  protocol_3  attack_0  attack_1  attack_2  \
# 46466580           0           1         0         0         1
# 35466168           0           1         0         0         1
# 32971698           1           0         0         1         0
# 14102806           0           1         0         1         1
# 38449210           0           1         0         0         1
# ...              ...         ...       ...       ...       ...
# 61629208           1           1         1         0         1
# 61629247           0           1         1         0         0
# 61629250           0           1         0         0         1
# 61629389           0           1         0         0         1
# 61629390           0           1         1         0         0
#
#           attacker_country_hour
# 46466580                  CN/12
# 35466168                   DE/4
# 32971698                  CN/12
# 14102806        Otros países/14
# 38449210                  DE/11
# ...                         ...
# 61629208                   CA/9
# 61629247                  SG/21
# 61629250                  SG/21
# 61629389                  SG/21
# 61629390                  SG/21
#
# [11077372 rows x 26 columns]

# %% [markdown]
# # Attacker Country Hour

# %% [markdown]
# Uso Mean Encoding para attacker_country_hour porque hay muchos valores diferentes.

# %%
encoder = ce.TargetEncoder(cols = ["attacker_country_hour"])
X_train = encoder.fit_transform(X_train, y_train)
X_validation = encoder.transform(X_validation)
X_test = encoder.transform(X_test)

X_train["attacker_country_hour"] = X_train["attacker_country_hour"].astype("float32")
X_validation["attacker_country_hour"] = X_validation["attacker_country_hour"].astype("float32")
X_test["attacker_country_hour"] = X_test["attacker_country_hour"].astype("float32")
X_train
# Out:
#           watcher_country_0  watcher_country_1  watcher_country_2  \
# 46466580                  0                  0                  0
# 35466168                  0                  0                  1
# 32971698                  0                  0                  1
# 14102806                  0                  0                  0
# 38449210                  0                  0                  1
# ...                     ...                ...                ...
# 61629208                  0                  1                  0
# 61629247                  0                  0                  1
# 61629250                  0                  0                  1
# 61629389                  0                  0                  1
# 61629390                  0                  0                  1
#
#           watcher_country_3  watcher_as_name  attacker_country_0  \
# 46466580                  1         0.053534                   0
# 35466168                  0         0.009843                   0
# 32971698                  1         0.050879                   0
# 14102806                  1         0.065808                   0
# 38449210                  0         0.009843                   0
# ...                     ...              ...                 ...
# 61629208                  0         0.207164                   0
# 61629247                  0         0.071613                   1
# 61629250                  0         0.071613                   1
# 61629389                  1         0.045860                   1
# 61629390                  1         0.045860                   1
#
#           attacker_country_1  attacker_country_2  attacker_country_3  \
# 46466580                   0                   0                   1
# 35466168                   0                   1                   0
# 32971698                   0                   0                   1
# 14102806                   0                   1                   1
# 38449210                   0                   1                   0
# ...                      ...                 ...                 ...
# 61629208                   1                   0                   0
# 61629247                   0                   1                   0
# 61629250                   0                   1                   0
# 61629389                   0                   1                   0
# 61629390                   0                   1                   0
#
#           attacker_as_name  ...  day_1  day_2  protocol_0  protocol_1  \
# 46466580          0.000000  ...      0      1           0           0
# 35466168          0.000000  ...      1      0           0           0
# 32971698          0.022648  ...      0      1           0           0
# 14102806          0.000000  ...      1      1           0           0
# 38449210          0.000000  ...      1      1           0           0
# ...                    ...  ...    ...    ...         ...         ...
# 61629208          0.334415  ...      0      0           0           0
# 61629247          0.111315  ...      0      1           0           0
# 61629250          0.111315  ...      0      1           0           0
# 61629389          0.111315  ...      0      1           0           0
# 61629390          0.111315  ...      0      1           0           0
#
#           protocol_2  protocol_3  attack_0  attack_1  attack_2  \
# 46466580           0           1         0         0         1
# 35466168           0           1         0         0         1
# 32971698           1           0         0         1         0
# 14102806           0           1         0         1         1
# 38449210           0           1         0         0         1
# ...              ...         ...       ...       ...       ...
# 61629208           1           1         1         0         1
# 61629247           0           1         1         0         0
# 61629250           0           1         0         0         1
# 61629389           0           1         0         0         1
# 61629390           0           1         1         0         0
#
#           attacker_country_hour
# 46466580               0.021599
# 35466168               0.051732
# 32971698               0.021599
# 14102806               0.025370
# 38449210               0.043263
# ...                         ...
# 61629208               0.050204
# 61629247               0.066620
# 61629250               0.066620
# 61629389               0.066620
# 61629390               0.066620
#
# [11077372 rows x 26 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11077372 entries, 46466580 to 61629390
# Data columns (total 26 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   watcher_country_0      int8
#  1   watcher_country_1      int8
#  2   watcher_country_2      int8
#  3   watcher_country_3      int8
#  4   watcher_as_name        float32
#  5   attacker_country_0     int8
#  6   attacker_country_1     int8
#  7   attacker_country_2     int8
#  8   attacker_country_3     int8
#  9   attacker_as_name       float32
#  10  hour                   float32
#  11  hour_range_(0-6)       int8
#  12  hour_range_(6-12)      int8
#  13  hour_range_(12-18)     int8
#  14  hour_range_(18-0)      int8
#  15  day_0                  int8
#  16  day_1                  int8
#  17  day_2                  int8
#  18  protocol_0             int8
#  19  protocol_1             int8
#  20  protocol_2             int8
#  21  protocol_3             int8
#  22  attack_0               int8
#  23  attack_1               int8
#  24  attack_2               int8
#  25  attacker_country_hour  float32
# dtypes: float32(4), int8(22)
# memory usage: 486.0 MB

# %% [markdown]
# # Random Forest

# %%
random_forest = RandomForestClassifier(random_state = 18)

# %% [markdown]
# # Random Search

# %% [markdown]
# Elijo estos hiperparámetros porque son los que consideré para obtener mejor score en el modelo.

# %%
parametros = {
    "max_depth": [1, 18],
    "min_samples_split": [2, 20],
    "min_samples_leaf": [1, 20],
    "class_weight": [None, "balanced"]
}

mejor_f1 = 0
batches = np.array_split(X_train, 100)

for batch in batches:
    random_search = RandomizedSearchCV(estimator = random_forest, param_distributions = parametros, n_iter = 10, cv = 5, scoring = "f1", random_state = 18, n_jobs = -1)
    random_search.fit(batch, y_train.loc[batch.index])

    random_forest_optimizado = random_search.best_estimator_

    y_prediction = random_forest_optimizado.predict(X_validation)
    f1 = f1_score(y_validation, y_prediction)

    if f1 > mejor_f1:
        mejor_f1 = f1
        hiperparametros = random_search.best_params_

hiperparametros
# Out:
# {'min_samples_split': 20,
#  'min_samples_leaf': 20,
#  'max_depth': 18,
#  'class_weight': None}

# %%
random_forest = RandomForestClassifier(n_estimators = 100, random_state = 18, **hiperparametros)
random_forest.fit(X_train, y_train)

y_prediction = random_forest.predict(X_validation)

# %%
f1_score(y_validation, y_prediction)
# Out:
# 0.741780731481889

# %% [markdown]
# ¿Cuál es el mejor score en la competencia? (Guardar el csv con predicciones para entregarlo después)

# %%
y_prediction = random_forest.predict(X_test)
y_prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int8)

# %%
predictions = pd.DataFrame({"label": y_prediction}).reset_index(drop = True)
X_test_ip = X_test_ip.reset_index(drop = True)

predicciones = pd.concat([X_test_ip, predictions], axis = 1)
predicciones
# Out:
#        attacker_ip_enum  label
# 0                     5      0
# 1                     7      0
# 2                    21      0
# 3                    29      0
# 4                    33      0
# ...                 ...    ...
# 49415            199947      0
# 49416            199949      0
# 49417            199962      0
# 49418            199964      0
# 49419            199966      0
#
# [49420 rows x 2 columns]

# %% [markdown]
# El score obtenido es: 0.55384

# %%
predicciones.to_csv("/content/drive/MyDrive/Colab Notebooks/predicciones_random_forest_batches.csv", index = False)

# %%
predicciones[predicciones["label"] == 1]
# Out:
#        attacker_ip_enum  label
# 13                   99      1
# 59                  299      1
# 128                 520      1
# 164                 645      1
# 174                 669      1
# ...                 ...    ...
# 49253            199335      1
# 49254            199340      1
# 49311            199570      1
# 49395            199861      1
# 49407            199914      1
#
# [1261 rows x 2 columns]

# %% [markdown]
# https://drive.google.com/file/d/1w5uCd2dNdjISVNoFGt0NvrvAFR_L8G9J/view?usp=drive_link
